# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc
import seaborn as sns

# %%
data=xr.open_dataset('g4.timeAvgMap.MODISA_L3m_SST4_8d_9km_R2019_0_sst4.20130101-20221231.2E_3N_8E_6N.nc')
print(data)
# Out:
# <xarray.Dataset>
# Dimensions:                              (lat: 35, lon: 70, latv: 2, lonv: 2)
# Coordinates:
#   * lat                                  (lat) float32 3.625 3.708 ... 6.458
#   * lon                                  (lon) float32 2.708 2.792 ... 8.458
# Dimensions without coordinates: latv, lonv
# Data variables:
#     MODISA_L3m_SST4_8d_9km_R2019_0_sst4  (lat, lon) float32 ...
#     lat_bnds                             (lat, latv) float64 ...
#     lon_bnds                             (lon, lonv) float64 ...
# Attributes:
#     Conventions:               CF-1.4
#     start_time:                2012-12-31T12:50:00Z
#     end_time:                  2022-12-31T23:59:59Z
#     NCO:                       netCDF Operators version 5.0.6 (Homepage = htt...
#     nco_openmp_thread_number:  1
#     history:                   Sun Aug 20 10:06:56 2023: ncks -O -x -v time_b...
#     userstartdate:             2013-01-01T00:00:00Z
# ...

# %%
data.data_vars
# Out:
# Data variables:
#     MODISA_L3m_SST4_8d_9km_R2019_0_sst4  (lat, lon) float32 ...
#     lat_bnds                             (lat, latv) float64 ...
#     lon_bnds                             (lon, lonv) float64 ...

# %%
data.lon
# Out:
# <xarray.DataArray 'lon' (lon: 70)>
# array([2.708338, 2.791667, 2.87501 , 2.958338, 3.041667, 3.12501 , 3.208338,
#        3.291667, 3.37501 , 3.458338, 3.541667, 3.62501 , 3.708338, 3.791667,
#        3.87501 , 3.958338, 4.041667, 4.12501 , 4.208338, 4.291667, 4.37501 ,
#        4.458338, 4.541667, 4.62501 , 4.708338, 4.791667, 4.87501 , 4.958338,
#        5.041667, 5.12501 , 5.208338, 5.291667, 5.37501 , 5.458338, 5.541667,
#        5.62501 , 5.708338, 5.791667, 5.87501 , 5.958338, 6.041667, 6.12501 ,
#        6.208338, 6.291667, 6.37501 , 6.458338, 6.541667, 6.62501 , 6.708338,
#        6.791667, 6.87501 , 6.958338, 7.041667, 7.12501 , 7.208338, 7.291667,
#        7.37501 , 7.458338, 7.541667, 7.62501 , 7.708338, 7.791667, 7.87501 ,
#        7.958338, 8.041667, 8.12501 , 8.208339, 8.291667, 8.37501 , 8.458339],
#       dtype=float32)
# Coordinates:
#   * lon      (lon) float32 2.708 2.792 2.875 2.958 ... 8.208 8.292 8.375 8.458
# Attributes:
#     units:          degrees_east
# ...

# %%
data.lat
# Out:
# <xarray.DataArray 'lat' (lat: 35)>
# array([3.624997, 3.708333, 3.791662, 3.874997, 3.958333, 4.041662, 4.124998,
#        4.208333, 4.291662, 4.374998, 4.458333, 4.541662, 4.624998, 4.708333,
#        4.791662, 4.874998, 4.958333, 5.041662, 5.124998, 5.208333, 5.291662,
#        5.374998, 5.458333, 5.541662, 5.624998, 5.708333, 5.791662, 5.874998,
#        5.958333, 6.041662, 6.124998, 6.208333, 6.291662, 6.374998, 6.458333],
#       dtype=float32)
# Coordinates:
#   * lat      (lat) float32 3.625 3.708 3.792 3.875 ... 6.208 6.292 6.375 6.458
# Attributes:
#     units:          degrees_north
#     valid_min:      -90.0
#     valid_max:      90.0
#     standard_name:  latitude
#     bounds:         lat_bnds

# %%
data. MODISA_L3m_SST4_8d_9km_R2019_0_sst4.plot()
