# %%
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
data=pd.read_csv('cover.csv',header=8,sep=",")
print(data)
# Out:
#                     Time  Temperature
# 0    2012-12-31 12:50:00    28.384722
# 1    2013-01-31 12:10:01    28.379208
# 2    2013-02-28 12:35:00    29.010454
# 3    2013-03-31 12:25:01    29.496632
# 4    2013-04-30 12:35:01    29.399357
# ..                   ...          ...
# 115   2022-08-01 0:00:00    23.928198
# 116   2022-09-01 0:00:00    25.030859
# 117   2022-10-01 0:00:00    27.984346
# 118   2022-11-01 0:00:00    29.298777
# 119   2022-12-01 0:00:00    28.811958
#
# [120 rows x 2 columns]

# %%
data.Time
# Out:
# 0      2012-12-31 12:50:00
# 1      2013-01-31 12:10:01
# 2      2013-02-28 12:35:00
# 3      2013-03-31 12:25:01
# 4      2013-04-30 12:35:01
#               ...
# 115     2022-08-01 0:00:00
# 116     2022-09-01 0:00:00
# 117     2022-10-01 0:00:00
# 118     2022-11-01 0:00:00
# 119     2022-12-01 0:00:00
# Name: Time, Length: 120, dtype: object

# %%
data.Time=pd.to_datetime(data.Time)
data=data.set_index('Time')
data
# Out:
#                      Temperature
# Time
# 2012-12-31 12:50:00    28.384722
# 2013-01-31 12:10:01    28.379208
# 2013-02-28 12:35:00    29.010454
# 2013-03-31 12:25:01    29.496632
# 2013-04-30 12:35:01    29.399357
# ...                          ...
# 2022-08-01 00:00:00    23.928198
# 2022-09-01 00:00:00    25.030859
# 2022-10-01 00:00:00    27.984346
# 2022-11-01 00:00:00    29.298777
# 2022-12-01 00:00:00    28.811958
#
# [120 rows x 1 columns]

# %%
data.plot()
# Out:
# <Axes: xlabel='Time'>

# %%
data.Temperature
# Out:
# Time
# 2012-12-31 12:50:00    28.384722
# 2013-01-31 12:10:01    28.379208
# 2013-02-28 12:35:00    29.010454
# 2013-03-31 12:25:01    29.496632
# 2013-04-30 12:35:01    29.399357
#                          ...
# 2022-08-01 00:00:00    23.928198
# 2022-09-01 00:00:00    25.030859
# 2022-10-01 00:00:00    27.984346
# 2022-11-01 00:00:00    29.298777
# 2022-12-01 00:00:00    28.811958
# Name: Temperature, Length: 120, dtype: float64
